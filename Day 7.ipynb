# %%
def get_age():
  try:
      age = int(input("what is your age ?"))
      print(f"Your age is {age}")
  except ValueError:
      print("Please enter a valid number")

get_age()
# Out:
# what is your age ?cat
# Please enter a valid number
