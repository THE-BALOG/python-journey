# %%
def calculate():
    x =int(input("what's x ? "))
    y =float(input("what's y ? "))
    print(x + y)
    print(x - y)
    print(x * y)
    print(x / y)
    print(x // y)
    print(x % y)

calculate()
# Out:
# what's x ? 5
# what's y ? 4
# 9.0
# 1.0
# 20.0
# 1.25
# 1.0
# 1.0
