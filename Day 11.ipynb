# %%
import requests
import json

response = requests.get("https://api.agify.io?name=David")

o = response.json()
print(o)
# Out:
# {'count': 546685, 'name': 'David', 'age': 64}

# %%
print(o['age'])
# Out:
# 64
