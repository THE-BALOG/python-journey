# %%
def main():
    a = int(input("what's a ? "))
    b = int(input("what's b ? "))
    print("The sum of x and y is", add(a,b))

def add(a,b):
  return a + b

if __name__ == "__main__":
    main()
# Out:
# what's a ? 3
# what's b ? 4
# The sum of x and y is 7

# %%
assert add(2, 3) == 5
assert add(0, 0) == 0
assert add(-1, 1) == 0
