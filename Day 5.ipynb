# %%
favourite_foods = ["Rice","Beans","Yam","Spag","Pizza"]
print("---My favourite foods---")

for favourite_food in favourite_foods:
    print("I love",favourite_food)


print("\n---Skipping those that start wit P---")


for favourite_food in favourite_foods:
    if favourite_food.startswith("P"):
      continue

    print("I love",favourite_food)
# Out:
# ---My favourite foods---
# I love Rice
# I love Beans
# I love Yam
# I love Spag
# I love Pizza
#
# ---Skipping those that start wit P---
# I love Rice
# I love Beans
# I love Yam
# I love Spag

# %%
myself = {
    "name" : "Balogun David",
    "age" : 20,
    "course" : "Mechanical Engineering",
    "favourite_language" : "English Language",
    "goal" : "Combine ME + AI and become rare"
}

for Key_name in myself:
    print(myself[Key_name])
# Out:
# Balogun David
# 20
# Mechanical Engineering
# English Language
# Combine ME + AI and become rare
