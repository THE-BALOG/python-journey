# %%
print("I started today ")
# Out:
# I started today

# %%
name = input("what is your name ? ").strip().title()

print(f"I am {name}")
# Out:
# what is your name ?            balogun david
# I am Balogun David

# %%
def introduction():
    name = input("What is your name? ").strip().title()
    course = input("What course are you studying? ")
    print(f"My name is {name} and I am {course} student.")

introduction()
# Out:
# What is your name?        balogun david
# What course are you studying? Mechanical Engineering
# My name is Balogun David and I am Mechanical Engineering  student.
